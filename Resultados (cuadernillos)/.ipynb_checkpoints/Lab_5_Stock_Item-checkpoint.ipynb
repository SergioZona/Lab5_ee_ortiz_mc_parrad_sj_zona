# %% [markdown]
# # SDC Type 2 implementation Stock Item

# %%
# Librerías para manejo de datos
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 25) # Número máximo de columnas a mostrar
pd.set_option('display.max_rows', 50) # Numero máximo de filas a mostar

# %%
 # carga del dataframe de stock item con datos actualizados
df_stock_item_new =pd.read_csv('dimension_stock_item_new.csv', sep=',', encoding = 'latin-1', index_col=None)

# %%
# Depuracion de StockItem con los valores a actualizar

# se elimina la primera fila de los nuevos datos porque todos sus valores son nulos o desconocidos
df_stock_item_new = df_stock_item_new[df_stock_item_new.Stock_Item != 'Unknown']
# se elimina la columna brand, dado que los datos originales no la tienen
df_stock_item_new.drop(['Brand'], axis = 1, inplace=True)
df_stock_item_new['Tax_Rate'] = [x.replace(',','.') for x in df_stock_item_new['Tax_Rate']]
df_stock_item_new['Unit_Price'] = [x.replace(',','.') for x in df_stock_item_new['Unit_Price']]
df_stock_item_new['Recommended_Retail_Price'] = [x.replace(',','.') for x in df_stock_item_new['Recommended_Retail_Price']]
df_stock_item_new['Typical_Weight_Per_Unit'] = [x.replace(',','.') for x in df_stock_item_new['Typical_Weight_Per_Unit']]
df_stock_item_new["Color"].fillna("NAN", inplace=True)
df_stock_item_new["Size_val"].fillna("NAN", inplace=True)

df_stock_item_new.head(5)
# Out:
#    Stock_Item_Key                        Stock_Item Color Selling_Package  \
# 1               1  Void fill 400 L bag (White) 400L  Blue            Each
# 2               2  Void fill 300 L bag (White) 300L  Blue            Each
# 3               3  Void fill 200 L bag (White) 200L  Blue            Each
# 4               4  Void fill 100 L bag (White) 100L   NAN            Each
# 5               5        Air cushion machine (Blue)  Gray            Each
#
#   Buying_Package Size_val  Lead_Time_Days  Quantity_Per_Outer  \
# 1           Each     400L              14                  10
# 2           Each     300L              14                  10
# 3           Each     200L              14                  10
# 4           Each     100L              14                  10
# 5           Each      NAN              20                   1
#
#    Is_Chiller_Stock Tax_Rate Unit_Price Recommended_Retail_Price  \
# 1             False   14.000      50.00                    74.75
# 2             False   14.000      37.50                    56.06
# 3             False   14.000      25.00                    37.38
# 4             False   14.000      12.50                    18.69
# 5             False   20.000    1899.00                  2839.01
#
#   Typical_Weight_Per_Unit
# 1                   1.000
# 2                    .750
# 3                    .500
# 4                    .250
# 5                  10.000

# %%
# ahora se pasará a hacer modelamiento de Slow Changing Dimension de tipo 2 para el conjunto de datos

# se hacen las importaciones y configuraciones necesarias necesarias para trabajar con SQL
from sqlalchemy import create_engine

# Postgres username, password, and database name
POSTGRES_ADDRESS = 'localhost' 
POSTGRES_PORT = '5432'
POSTGRES_USERNAME = 'postgres' 
POSTGRES_PASSWORD = 'password'
POSTGRES_DBNAME = 'lab5_wwi'
# A long string that contains the necessary Postgres login information
postgres_str = ('postgresql://{username}:{password}@{ipaddress}:{port}/{dbname}'
.format(username=POSTGRES_USERNAME,
password=POSTGRES_PASSWORD,
ipaddress=POSTGRES_ADDRESS,
port=POSTGRES_PORT,
dbname=POSTGRES_DBNAME))
# Create the connection
cnx = create_engine(postgres_str)

# %%
#query target table
stockitem_df=pd.read_sql_query('select * from stockitem',cnx)
stockitem_df.head(5)
# Out:
#    stock_item_key                                         stock_item color  \
# 0              18  Red and white urgent  heavy despatch tape  48m...   NAN
# 1              19        Red and white urgent despatch tape 48mmx75m   NAN
# 2              20     Black and yellow heavy despatch tape 48mmx100m   NAN
# 3              21     Black and yellow heavy despatch tape  48mmx75m   NAN
# 4              22  Black and orange this way up despatch tape  48...   NAN
#
#   selling_package buying_package   size_val  lead_time_days  \
# 0            Each           Each  48mmx100m              14
# 1            Each           Each   48mmx75m              14
# 2            Each           Each  48mmx100m              14
# 3            Each           Each   48mmx75m              14
# 4            Each           Each  48mmx100m              14
#
#    quantity_per_outer  is_chiller_stock  tax_rate  unit_price  \
# 0                  24             False      14.0         4.0
# 1                  24             False      14.0         4.0
# 2                  24             False      14.0         4.0
# 3                  24             False      14.0         4.0
# 4                  24             False      14.0         4.0
#
#    recommended_retail_price  typical_weight_per_unit
# 0                       6.0                      1.0
# 1                       6.0                      0.0
# 2                       6.0                      1.0
# 3                       6.0                      0.0
# 4                       6.0                      1.0

# %%
import datetime

# %%
stockitem_historia=stockitem_df

#Añadimos un versionamiento a los valoes actuales
stockitem_historia["Version"]=1

# añadimos fechas a los valores actuales
stockitem_historia["date_from"]= datetime.datetime(1900, 1, 1)
stockitem_historia["date_to"]= datetime.datetime(2199, 12, 31)

stockitem_historia.head(5)
# Out:
#    stock_item_key                                         stock_item color  \
# 0              18  Red and white urgent  heavy despatch tape  48m...   NAN
# 1              19        Red and white urgent despatch tape 48mmx75m   NAN
# 2              20     Black and yellow heavy despatch tape 48mmx100m   NAN
# 3              21     Black and yellow heavy despatch tape  48mmx75m   NAN
# 4              22  Black and orange this way up despatch tape  48...   NAN
#
#   selling_package buying_package   size_val  lead_time_days  \
# 0            Each           Each  48mmx100m              14
# 1            Each           Each   48mmx75m              14
# 2            Each           Each  48mmx100m              14
# 3            Each           Each   48mmx75m              14
# 4            Each           Each  48mmx100m              14
#
#    quantity_per_outer  is_chiller_stock  tax_rate  unit_price  \
# 0                  24             False      14.0         4.0
# 1                  24             False      14.0         4.0
# 2                  24             False      14.0         4.0
# 3                  24             False      14.0         4.0
# 4                  24             False      14.0         4.0
#
#    recommended_retail_price  typical_weight_per_unit  Version  date_from  \
# 0                       6.0                      1.0        1 1900-01-01
# 1                       6.0                      0.0        1 1900-01-01
# 2                       6.0                      1.0        1 1900-01-01
# 3                       6.0                      0.0        1 1900-01-01
# 4                       6.0                      1.0        1 1900-01-01
#
#      date_to
# 0 2199-12-31
# 1 2199-12-31
# 2 2199-12-31
# 3 2199-12-31
# 4 2199-12-31

# %%
# se insertan los valores en la base de datos, en este caso en una nueva tabla
#stockitem_historia.to_sql('stockitem_historia',con=cnx,if_exists='append',index=False)

# %%
# ahora lo que se necesita hacer es crear un algoritmo que garantice que con el ingreso de los nuevos datos
# se pueda modelar una Slowly Changing Dimension de tipo 2

# el algoritmo es el siguiente:
# se recorre todo el dataframe de los datos nuevos y se pone atención en el valor de stock_item_key
# si dicho valor existe en la tabla original de datos y alguno de los atributos iniciales ha cambiado, se procederá a hacer la inserción de un nuevo registro en el dataframe de historias
# la versión del nuevo registró será igual al número de la versión más reciente que contiene dicho id más 1
# asimismo, a la versión más reciente se le cambiará la fecha final por la fecha actual
# y a la nueva versión se le pondrá como fecha inicial la actual y como fecha final 2199-12-31

for row in df_stock_item_new.iterrows():
    stock_item_key = row[1]["Stock_Item_Key"]
    
    version = 0
    # ahora se recorre el antiguo dataframe
    indice = 0
    indice_real = 0
    usar_indice_real = False
    for row2 in stockitem_historia.iterrows():
        key = row2[1]["stock_item_key"]
        if stock_item_key == key:
            ver = row2[1]["Version"] # version
            if(ver > version):
                version = ver
                indice_real = indice
            usar_indice_real = True
        indice+=1
    
    # hay que detectar si hubo algún cambio respecto a la version final
    if( usar_indice_real and
        (row[1]["Stock_Item"] != stockitem_historia.loc[indice_real]["stock_item"] or
        row[1]["Color"] != stockitem_historia.loc[indice_real]["color"] or
        row[1]["Selling_Package"] != stockitem_historia.loc[indice_real]["selling_package"] or
        row[1]["Buying_Package"] != stockitem_historia.loc[indice_real]["buying_package"] or
        row[1]["Size_val"] != stockitem_historia.loc[indice_real]["size_val"] or
        row[1]["Lead_Time_Days"] != stockitem_historia.loc[indice_real]["lead_time_days"] or
        row[1]["Quantity_Per_Outer"] != stockitem_historia.loc[indice_real]["quantity_per_outer"] or
        row[1]["Is_Chiller_Stock"] != stockitem_historia.loc[indice_real]["is_chiller_stock"] or
        row[1]["Tax_Rate"] != stockitem_historia.loc[indice_real]["tax_rate"] or
        row[1]["Unit_Price"] != stockitem_historia.loc[indice_real]["unit_price"] or
        row[1]["Recommended_Retail_Price"] != stockitem_historia.loc[indice_real]["recommended_retail_price"] or
        row[1]["Typical_Weight_Per_Unit"] != stockitem_historia.loc[indice_real]["typical_weight_per_unit"] ) ):
        
            dt = datetime.datetime.now()
            stockitem_historia.loc[indice_real,['date_to']] = datetime.datetime(dt.year, dt.month, dt.day)
            row_a_agregar = stockitem_historia.loc[indice_real]
            row_a_agregar["Version"] = version + 1
            dt = datetime.datetime.now()
            
            row_a_agregar["stock_item"] = row[1]["Stock_Item"]
            row_a_agregar["color"] = row[1]["Color"]
            row_a_agregar["selling_package"] = row[1]["Selling_Package"]
            row_a_agregar["buying_package"] = row[1]["Buying_Package"]
            row_a_agregar["size_val"] = row[1]["Size_val"]
            row_a_agregar["lead_time_days"] = row[1]["Lead_Time_Days"]
            row_a_agregar["quantity_per_outer"] = row[1]["Quantity_Per_Outer"]
            row_a_agregar["is_chiller_stock"] = row[1]["Is_Chiller_Stock"]
            row_a_agregar["tax_rate"] = row[1]["Tax_Rate"]
            row_a_agregar["unit_price"] = row[1]["Unit_Price"]
            row_a_agregar["recommended_retail_Price"] = row[1]["Recommended_Retail_Price"]
            row_a_agregar["typical_Weight_Per_Unit"] = row[1]["Typical_Weight_Per_Unit"]
            
            row_a_agregar["date_from"] = datetime.datetime(dt.year, dt.month, dt.day)
            row_a_agregar["date_to"] = datetime.datetime(2199, 12, 31)
            stockitem_historia = stockitem_historia.append(row_a_agregar, ignore_index=True)
# Out:
# <ipython-input-9-53dfbdfa218d>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["Version"] = version + 1
# <ipython-input-9-53dfbdfa218d>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["stock_item"] = row[1]["Stock_Item"]
# <ipython-input-9-53dfbdfa218d>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["color"] = row[1]["Color"]
# <ipython-input-9-53dfbdfa218d>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["selling_package"] = row[1]["Selling_Package"]
# <ipython-input-9-53dfbdfa218d>:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["buying_package"] = row[1]["Buying_Package"]
# <ipython-input-9-53dfbdfa218d>:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["size_val"] = row[1]["Size_val"]
# <ipython-input-9-53dfbdfa218d>:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["lead_time_days"] = row[1]["Lead_Time_Days"]
# <ipython-input-9-53dfbdfa218d>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["quantity_per_outer"] = row[1]["Quantity_Per_Outer"]
# <ipython-input-9-53dfbdfa218d>:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["is_chiller_stock"] = row[1]["Is_Chiller_Stock"]
# <ipython-input-9-53dfbdfa218d>:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["tax_rate"] = row[1]["Tax_Rate"]
# <ipython-input-9-53dfbdfa218d>:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["unit_price"] = row[1]["Unit_Price"]
# <ipython-input-9-53dfbdfa218d>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["recommended_retail_Price"] = row[1]["Recommended_Retail_Price"]
# C:\Users\esteb\anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# <ipython-input-9-53dfbdfa218d>:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["typical_Weight_Per_Unit"] = row[1]["Typical_Weight_Per_Unit"]
# <ipython-input-9-53dfbdfa218d>:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["date_from"] = datetime.datetime(dt.year, dt.month, dt.day)
# <ipython-input-9-53dfbdfa218d>:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   row_a_agregar["date_to"] = datetime.datetime(2199, 12, 31)

# %%
stockitem_historia
# Out:
#       stock_item_key                                         stock_item  \
# 0                 18  Red and white urgent  heavy despatch tape  48m...
# 1                 19        Red and white urgent despatch tape 48mmx75m
# 2                 20     Black and yellow heavy despatch tape 48mmx100m
# 3                 21     Black and yellow heavy despatch tape  48mmx75m
# 4                 22  Black and orange this way up despatch tape  48...
# ...              ...                                                ...
# 1337             667                         Air cushion machine (Blue)
# 1338             668                   Void fill 100 L bag (White) 100L
# 1339             669                   Void fill 200 L bag (White) 200L
# 1340             670                   Void fill 300 L bag (White) 300L
# 1341             671                   Void fill 400 L bag (White) 400L
#
#       color selling_package buying_package   size_val  lead_time_days  \
# 0       NAN            Each           Each  48mmx100m              14
# 1       NAN            Each           Each   48mmx75m              14
# 2       NAN            Each           Each  48mmx100m              14
# 3       NAN            Each           Each   48mmx75m              14
# 4       NAN            Each           Each  48mmx100m              14
# ...     ...             ...            ...        ...             ...
# 1337  Green            Each           Each        NAN              20
# 1338    NAN            Each           Each       100L              14
# 1339    NAN            Each           Each       200L              14
# 1340    NAN            Each           Each       300L              14
# 1341    NAN            Each           Each       400L              14
#
#       quantity_per_outer  is_chiller_stock tax_rate unit_price  \
# 0                     24             False     14.0        4.0
# 1                     24             False     14.0        4.0
# 2                     24             False     14.0        4.0
# 3                     24             False     14.0        4.0
# 4                     24             False     14.0        4.0
# ...                  ...               ...      ...        ...
# 1337                   1             False   20.000    1899.00
# 1338                  10             False   14.000      12.50
# 1339                  10             False   14.000      25.00
# 1340                  10             False   14.000      37.50
# 1341                  10             False   14.000      50.00
#
#       recommended_retail_price  typical_weight_per_unit  Version  date_from  \
# 0                          6.0                      1.0        1 1900-01-01
# 1                          6.0                      0.0        1 1900-01-01
# 2                          6.0                      1.0        1 1900-01-01
# 3                          6.0                      0.0        1 1900-01-01
# 4                          6.0                      1.0        1 1900-01-01
# ...                        ...                      ...      ...        ...
# 1337                    2839.0                     10.0        2 2021-11-20
# 1338                      19.0                      0.0        2 2021-11-20
# 1339                      37.0                      0.0        2 2021-11-20
# 1340                      56.0                      1.0        2 2021-11-20
# 1341                      75.0                      1.0        2 2021-11-20
#
#         date_to recommended_retail_Price typical_Weight_Per_Unit
# 0    2021-11-20                      NaN                     NaN
# 1    2021-11-20                      NaN                     NaN
# 2    2021-11-20                      NaN                     NaN
# 3    2021-11-20                      NaN                     NaN
# 4    2021-11-20                      NaN                     NaN
# ...         ...                      ...                     ...
# 1337 2199-12-31                  2839.01                  10.000
# 1338 2199-12-31                    18.69                    .250
# 1339 2199-12-31                    37.38                    .500
# 1340 2199-12-31                    56.06                    .750
# 1341 2199-12-31                    74.75                   1.000
#
# [1342 rows x 18 columns]

# %%
# como ahora solo queda ordenar el dataframe en función del stock item key para que se pueda notar el cambio de los registros respecto a una SCD de tipo 2
stockitem_historia = stockitem_historia.sort_values(['stock_item_key', 'date_from'])

# reset indexes
stockitem_historia = stockitem_historia.reset_index(drop=True)

# ahora se le coloca una llave subrogada que identifique a cada uno de los valores de la tabla
stockitem_historia["tk_stock_item"] = stockitem_historia.index + 1

# shift column 'tk_stock_item' to first position
first_column = stockitem_historia.pop('tk_stock_item')
stockitem_historia.insert(0, 'tk_stock_item', first_column)

stockitem_historia.head(20)
# Out:
#     tk_stock_item  stock_item_key  \
# 0               1               1
# 1               2               1
# 2               3               2
# 3               4               2
# 4               5               3
# 5               6               3
# 6               7               4
# 7               8               4
# 8               9               5
# 9              10               5
# 10             11               6
# 11             12               6
# 12             13               7
# 13             14               7
# 14             15               8
# 15             16               8
# 16             17               9
# 17             18               9
# 18             19              10
# 19             20              10
#
#                                            stock_item color selling_package  \
# 0                    Void fill 400 L bag (White) 400L   NAN            Each
# 1                    Void fill 400 L bag (White) 400L  Blue            Each
# 2                    Void fill 300 L bag (White) 300L   NAN            Each
# 3                    Void fill 300 L bag (White) 300L  Blue            Each
# 4                    Void fill 200 L bag (White) 200L   NAN            Each
# 5                    Void fill 200 L bag (White) 200L  Blue            Each
# 6                    Void fill 100 L bag (White) 100L   NAN            Each
# 7                    Void fill 100 L bag (White) 100L   NAN            Each
# 8                          Air cushion machine (Blue)   NAN            Each
# 9                          Air cushion machine (Blue)  Gray            Each
# 10                  Air cushion film 200mmx200mm 325m   NAN            Each
# 11                  Air cushion film 200mmx200mm 325m   NAN            Each
# 12                  Air cushion film 200mmx100mm 325m   NAN            Each
# 13                  Air cushion film 200mmx100mm 325m   NAN            Each
# 14                     Large  replacement blades 18mm   NAN            Each
# 15                     Large  replacement blades 18mm   NAN            Each
# 16                   Small 9mm replacement blades 9mm   NAN            Each
# 17                   Small 9mm replacement blades 9mm   NAN            Each
# 18  Packing knife with metal insert blade (Yellow)...   NAN            Each
# 19  Packing knife with metal insert blade (Yellow)...   NAN            Each
#
#    buying_package size_val  lead_time_days  quantity_per_outer  \
# 0            Each     400L              14                  10
# 1            Each     400L              14                  10
# 2            Each     300L              14                  10
# 3            Each     300L              14                  10
# 4            Each     200L              14                  10
# 5            Each     200L              14                  10
# 6            Each     100L              14                  10
# 7            Each     100L              14                  10
# 8            Each      NAN              20                   1
# 9            Each      NAN              20                   1
# 10           Each     325m              14                   1
# 11           Each     325m              14                   1
# 12           Each     325m              14                   1
# 13           Each     325m              14                   1
# 14           Each     18mm              14                  10
# 15           Each     18mm              14                  10
# 16           Each      9mm              14                  10
# 17           Each      9mm              14                  10
# 18           Each     18mm              14                   5
# 19           Each     18mm              14                   5
#
#     is_chiller_stock tax_rate unit_price  recommended_retail_price  \
# 0              False     14.0       50.0                      75.0
# 1              False   14.000      50.00                      75.0
# 2              False     14.0       38.0                      56.0
# 3              False   14.000      37.50                      56.0
# 4              False     14.0       25.0                      37.0
# 5              False   14.000      25.00                      37.0
# 6              False     14.0       12.0                      19.0
# 7              False   14.000      12.50                      19.0
# 8              False     20.0     1899.0                    2839.0
# 9              False   20.000    1899.00                    2839.0
# 10             False     14.0       90.0                     135.0
# 11             False   14.000      90.00                     135.0
# 12             False     14.0       87.0                     130.0
# 13             False   14.000      87.00                     130.0
# 14             False     14.0        4.0                       6.0
# 15             False   14.000       4.30                       6.0
# 16             False     14.0        4.0                       6.0
# 17             False   14.000       4.10                       6.0
# 18             False     14.0        2.0                       4.0
# 19             False   14.000       2.40                       4.0
#
#     typical_weight_per_unit  Version  date_from    date_to  \
# 0                       1.0        1 1900-01-01 2021-11-20
# 1                       1.0        2 2021-11-20 2199-12-31
# 2                       1.0        1 1900-01-01 2021-11-20
# 3                       1.0        2 2021-11-20 2199-12-31
# 4                       0.0        1 1900-01-01 2021-11-20
# 5                       0.0        2 2021-11-20 2199-12-31
# 6                       0.0        1 1900-01-01 2021-11-20
# 7                       0.0        2 2021-11-20 2199-12-31
# 8                      10.0        1 1900-01-01 2021-11-20
# 9                      10.0        2 2021-11-20 2199-12-31
# 10                      6.0        1 1900-01-01 2021-11-20
# 11                      6.0        2 2021-11-20 2199-12-31
# 12                      5.0        1 1900-01-01 2021-11-20
# 13                      5.0        2 2021-11-20 2199-12-31
# 14                      1.0        1 1900-01-01 2021-11-20
# 15                      1.0        2 2021-11-20 2199-12-31
# 16                      1.0        1 1900-01-01 2021-11-20
# 17                      1.0        2 2021-11-20 2199-12-31
# 18                      0.0        1 1900-01-01 2021-11-20
# 19                      0.0        2 2021-11-20 2199-12-31
#
#    recommended_retail_Price typical_Weight_Per_Unit
# 0                       NaN                     NaN
# 1                     74.75                   1.000
# 2                       NaN                     NaN
# 3                     56.06                    .750
# 4                       NaN                     NaN
# 5                     37.38                    .500
# 6                       NaN                     NaN
# 7                     18.69                    .250
# 8                       NaN                     NaN
# 9                   2839.01                  10.000
# 10                      NaN                     NaN
# 11                   134.55                   6.000
# 12                      NaN                     NaN
# 13                   130.07                   5.000
# 14                      NaN                     NaN
# 15                     6.43                    .800
# 16                      NaN                     NaN
# 17                     6.13                    .700
# 18                      NaN                     NaN
# 19                     3.59                    .500

# %%
# se guardan las historias en un csv
stockitem_historia.to_csv('stockitem_historia.csv', encoding="utf-8", index=False)

# %%
# se insertan los valores de las historias en la base de datos, en este caso en la tabla stockitem_historia
stockitem_historia.to_sql('stockitem_historia',con=cnx,if_exists='append',index=False)

# %%
# se lee la tabla en la base de datos par comprobar que todo esté bien
stockitem_historia=pd.read_sql_query('select * from stockitem_historia',cnx)
stockitem_historia = stockitem_historia.sort_values(['stock_item_key', 'date_from'])
stockitem_historia.head(20)
# Out:
#     tk_stock_item  stock_item_key  \
# 0               1               1
# 1               2               1
# 2               3               2
# 3               4               2
# 4               5               3
# 5               6               3
# 6               7               4
# 7               8               4
# 8               9               5
# 9              10               5
# 10             11               6
# 11             12               6
# 12             13               7
# 13             14               7
# 14             15               8
# 15             16               8
# 16             17               9
# 17             18               9
# 18             19              10
# 19             20              10
#
#                                            stock_item color selling_package  \
# 0                    Void fill 400 L bag (White) 400L   NAN            Each
# 1                    Void fill 400 L bag (White) 400L  Blue            Each
# 2                    Void fill 300 L bag (White) 300L   NAN            Each
# 3                    Void fill 300 L bag (White) 300L  Blue            Each
# 4                    Void fill 200 L bag (White) 200L   NAN            Each
# 5                    Void fill 200 L bag (White) 200L  Blue            Each
# 6                    Void fill 100 L bag (White) 100L   NAN            Each
# 7                    Void fill 100 L bag (White) 100L   NAN            Each
# 8                          Air cushion machine (Blue)   NAN            Each
# 9                          Air cushion machine (Blue)  Gray            Each
# 10                  Air cushion film 200mmx200mm 325m   NAN            Each
# 11                  Air cushion film 200mmx200mm 325m   NAN            Each
# 12                  Air cushion film 200mmx100mm 325m   NAN            Each
# 13                  Air cushion film 200mmx100mm 325m   NAN            Each
# 14                     Large  replacement blades 18mm   NAN            Each
# 15                     Large  replacement blades 18mm   NAN            Each
# 16                   Small 9mm replacement blades 9mm   NAN            Each
# 17                   Small 9mm replacement blades 9mm   NAN            Each
# 18  Packing knife with metal insert blade (Yellow)...   NAN            Each
# 19  Packing knife with metal insert blade (Yellow)...   NAN            Each
#
#    buying_package size_val  lead_time_days  quantity_per_outer  \
# 0            Each     400L              14                  10
# 1            Each     400L              14                  10
# 2            Each     300L              14                  10
# 3            Each     300L              14                  10
# 4            Each     200L              14                  10
# 5            Each     200L              14                  10
# 6            Each     100L              14                  10
# 7            Each     100L              14                  10
# 8            Each      NAN              20                   1
# 9            Each      NAN              20                   1
# 10           Each     325m              14                   1
# 11           Each     325m              14                   1
# 12           Each     325m              14                   1
# 13           Each     325m              14                   1
# 14           Each     18mm              14                  10
# 15           Each     18mm              14                  10
# 16           Each      9mm              14                  10
# 17           Each      9mm              14                  10
# 18           Each     18mm              14                   5
# 19           Each     18mm              14                   5
#
#     is_chiller_stock tax_rate unit_price  recommended_retail_price  \
# 0              False     14.0       50.0                      75.0
# 1              False   14.000      50.00                      75.0
# 2              False     14.0       38.0                      56.0
# 3              False   14.000      37.50                      56.0
# 4              False     14.0       25.0                      37.0
# 5              False   14.000      25.00                      37.0
# 6              False     14.0       12.0                      19.0
# 7              False   14.000      12.50                      19.0
# 8              False     20.0     1899.0                    2839.0
# 9              False   20.000    1899.00                    2839.0
# 10             False     14.0       90.0                     135.0
# 11             False   14.000      90.00                     135.0
# 12             False     14.0       87.0                     130.0
# 13             False   14.000      87.00                     130.0
# 14             False     14.0        4.0                       6.0
# 15             False   14.000       4.30                       6.0
# 16             False     14.0        4.0                       6.0
# 17             False   14.000       4.10                       6.0
# 18             False     14.0        2.0                       4.0
# 19             False   14.000       2.40                       4.0
#
#     typical_weight_per_unit  Version  date_from    date_to  \
# 0                       1.0        1 1900-01-01 2021-11-20
# 1                       1.0        2 2021-11-20 2199-12-31
# 2                       1.0        1 1900-01-01 2021-11-20
# 3                       1.0        2 2021-11-20 2199-12-31
# 4                       0.0        1 1900-01-01 2021-11-20
# 5                       0.0        2 2021-11-20 2199-12-31
# 6                       0.0        1 1900-01-01 2021-11-20
# 7                       0.0        2 2021-11-20 2199-12-31
# 8                      10.0        1 1900-01-01 2021-11-20
# 9                      10.0        2 2021-11-20 2199-12-31
# 10                      6.0        1 1900-01-01 2021-11-20
# 11                      6.0        2 2021-11-20 2199-12-31
# 12                      5.0        1 1900-01-01 2021-11-20
# 13                      5.0        2 2021-11-20 2199-12-31
# 14                      1.0        1 1900-01-01 2021-11-20
# 15                      1.0        2 2021-11-20 2199-12-31
# 16                      1.0        1 1900-01-01 2021-11-20
# 17                      1.0        2 2021-11-20 2199-12-31
# 18                      0.0        1 1900-01-01 2021-11-20
# 19                      0.0        2 2021-11-20 2199-12-31
#
#    recommended_retail_Price typical_Weight_Per_Unit
# 0                      None                    None
# 1                     74.75                   1.000
# 2                      None                    None
# 3                     56.06                    .750
# 4                      None                    None
# 5                     37.38                    .500
# 6                      None                    None
# 7                     18.69                    .250
# 8                      None                    None
# 9                   2839.01                  10.000
# 10                     None                    None
# 11                   134.55                   6.000
# 12                     None                    None
# 13                   130.07                   5.000
# 14                     None                    None
# 15                     6.43                    .800
# 16                     None                    None
# 17                     6.13                    .700
# 18                     None                    None
# 19                     3.59                    .500
